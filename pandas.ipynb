# %%
import pandas as pd
from pandas import Series,DataFrame
s = Series([1,2,3],index=['a','b','c'])
print(s)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
sdata1 = {'name':['a','b','c'],'rank':[1,2,3],'score':[99,87,45]}
df1 =DataFrame(sdata1)
df2 =DataFrame(sdata1,columns=['score','rank','name']) 
df3 =DataFrame(sdata1,columns=['score','rank','name','class']) 
print('\n',df1)
print(df2)
del df3['class']
# df3
# df3.T
# print(df1.columns)
# df3.reindex(['1','2','3','4'],method='bfill')
# print(df3)
# Out:
#    name  rank  score
# 0    a     1     99
# 1    b     2     87
# 2    c     3     45
#    score  rank name
# 0     99     1    a
# 1     87     2    b
# 2     45     3    c

# %%
import pandas as pd
exc=pd.read_csv('C:\\Users\\wen\\Desktop\\tips.csv')
# excle=pd.read_excel("C:\\Users\\wen\\Desktop\\xxxx.xlsx")
print(exc.head())
# exc1=pd.read_table('C:\\Users\\wen\\Desktop\\tips.csv')
# exc2=pd.read_table('C:\\Users\\wen\\Desktop\\tips.csv',sep=',')
# excle1=pd.read_table('C:\\Users\\wen\\Desktop\\xxxxx.xlsx',sep=',')
# print(exc1.head())
# print(exc2.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
tips = pd.read_csv('C:\\Users\\wen\\Desktop\\tips.csv')
tips[['sex','smoker','day','time']].describe()
tips['sex'].value_counts()
tips['sex']
print(tips[:5])
tips.at[1,'sex']
tips.iat[4,4]
tips.loc[:,['sex','size']]
tips.iloc[0,2]
tips.iloc[0:4,2:4]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#       sex smoker
# 0  Female     No
# 1    Male     No
# 2    Male     No
# 3    Male     No

# %%
import pandas as pd
from pandas import Series,DataFrame
left = pd.DataFrame({'key':['foo','foo'],'lval':[1,2]})
right = pd.DataFrame({'key':['foo','foo'],'rval':[4,5]})
pd.merge(left,right,on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from pandas import Series,DataFrame
# tips = pd.read_csv('C:\\Users\\wen\\Desktop\\tips.csv')
# tips1['tips_pct']=tips1['tip']/tips1['total_bill']
# tips1['tips_pct'].hist(bins=50)
changes= DataFrame(np.random.normal(loc=0.1,scale=0.25,size=(100,10)))
returns= changes.cumsum(0)
returns.plot()
